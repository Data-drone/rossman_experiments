# %%
# %run LSTM_Model_5.py
# Out:
# Using TensorFlow backend.
# Train on 834205 samples, validate on 10133 samples
# Epoch 1/350
#  - 100s - loss: 0.0036 - val_loss: 0.0025
# Epoch 2/350
#  - 105s - loss: 0.0024 - val_loss: 0.0024
# Epoch 3/350
#  - 108s - loss: 0.0024 - val_loss: 0.0024
# Epoch 4/350
#  - 109s - loss: 0.0024 - val_loss: 0.0024
# Epoch 5/350
#  - 107s - loss: 0.0024 - val_loss: 0.0023
# Epoch 6/350
#  - 101s - loss: 0.0024 - val_loss: 0.0023
# Epoch 7/350
#  - 100s - loss: 0.0023 - val_loss: 0.0022
# Epoch 8/350
#  - 100s - loss: 0.0023 - val_loss: 0.0022
# Epoch 9/350
#  - 103s - loss: 0.0023 - val_loss: 0.0021
# Epoch 10/350
#  - 102s - loss: 0.0022 - val_loss: 0.0022
# Epoch 11/350
#  - 102s - loss: 0.0022 - val_loss: 0.0021
# Epoch 12/350
#  - 101s - loss: 0.0022 - val_loss: 0.0021
# Epoch 13/350
#  - 105s - loss: 0.0022 - val_loss: 0.0022
# Epoch 14/350
#  - 99s - loss: 0.0022 - val_loss: 0.0022
# Epoch 15/350
#  - 99s - loss: 0.0022 - val_loss: 0.0022
# Epoch 16/350
# ...

# %%
model.save('model/LSTM_Model_5.h5')
